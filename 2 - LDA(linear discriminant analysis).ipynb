# %%
import numpy as np
from sklearn.linear_model import LogisticRegression

# %%
height = np.array([140,145,135,169,165,142,168,141,159,160,172])
gender = np.array(['F','F','F','M','F','M','M','F','F','M','M'])

lg = LogisticRegression()

# %%
lg.fit(height,gender)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-960f763997f6> in <cell line: 1>()
# ----> 1 lg.fit(height,gender)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1194             _dtype = [np.float64, np.float32]
#    1195
# -> 1196         X, y = self._validate_data(
#    1197             X,
#    1198             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# ...

# %%
lda.fit(height.reshape(-1,1),gender)
x = np.array([155])
lda.predict_proba(x.reshape(-1,1))
# Out:
# array([[0.5407828, 0.4592172]])

# %%
lda.predict(x.reshape(-1,1))
# Out:
# array(['F'], dtype='<U1')
